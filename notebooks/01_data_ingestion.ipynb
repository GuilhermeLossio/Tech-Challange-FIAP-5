# %% [markdown]
# # 01 - Data Ingestion
#
# Downloads the public Hillstrom Kaggle dataset into the local raw data folder. This notebook requires Kaggle credentials configured outside the notebook.

# %%
from pathlib import Path

raw_dir = Path('..') / 'data' / 'raw'
raw_dir.mkdir(parents=True, exist_ok=True)
raw_dir

# %%
# Run from the repository root when Kaggle credentials are configured.
# !python -m src.evaluation.run --prepare-data --max-rows 5000
