# %% [markdown]
# # 02 - Data Processing And Validation
#
# Processes the Hillstrom source file into minimized context, action, and reward columns, then validates the processed dataset.

# %%
# Run from the repository root after ingestion.
# !python -m src.data.process
# !python -m src.data.validate

# %%
import json
from pathlib import Path

report_path = Path('..') / 'reports' / 'data_validation.json'
if report_path.exists():
    json.loads(report_path.read_text(encoding='utf-8'))
else:
    {'status': 'Run validation first'}
