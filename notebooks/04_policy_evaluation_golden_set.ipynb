# %% [markdown]
# # 04 - Policy Evaluation and Golden Set
#
# Inspect policy metrics and deterministic Golden Set recommendations generated by the training runner.
#
# ## Review Focus
#
# - Confirm which policy was selected.
# - Compare reward, regret, and exploration metrics.
# - Review example recommendations for Demo Day and governance discussion.

# %%
import json
from pathlib import Path

repo_root = Path.cwd()
if repo_root.name == 'notebooks':
    repo_root = repo_root.parent

report_dir = repo_root / 'reports' / 'policy_training'
metrics_path = report_dir / 'metrics.json'
selected_path = report_dir / 'selected_policy.json'
golden_set_path = report_dir / 'golden_set_recommendations.json'

{
    'metrics_exists': metrics_path.exists(),
    'selected_policy_exists': selected_path.exists(),
    'golden_set_exists': golden_set_path.exists(),
}

# %% [markdown]
# ## Selected Policy and Metrics

# %%
result = {}
if selected_path.exists():
    result['selected_policy'] = json.loads(selected_path.read_text(encoding='utf-8'))
if metrics_path.exists():
    result['metrics'] = json.loads(metrics_path.read_text(encoding='utf-8'))

result or {'status': 'missing', 'next_step': 'Run python -m src.evaluation.run.'}

# %% [markdown]
# ## Current Validated Metrics
#
# The current full offline evaluation selected `baseline` as the offline promoted policy. It ran 17,232 evaluation rounds and produced cumulative reward `252` with conversion rate `0.014624`.
#
# This does not mean the online API must serve a bandit strategy at request time. Offline promoted policy evidence and the online serving strategy reported by `/v1/policies/current` must stay separate in reviews and demos.

# %%
current_validated_metrics = {
    'selected_offline_policy': 'baseline',
    'evaluation_rounds': 17232,
    'cumulative_reward': 252,
    'conversion_rate': 0.014624,
    'cumulative_regret': 0.0,
    'exploration_rate': 0.0,
    'separation_note': 'Offline promoted policy evidence is not the same thing as the online serving strategy.',
}
current_validated_metrics

# %% [markdown]
# ## Golden Set Recommendations
#
# The current Golden Set has 5 deterministic examples generated from the selected offline policy. For run `train-20260727T211636Z-43b893e`, all examples recommend `mens_email` under the `baseline` policy with `offline_reward_evidence` and `policy_comparison_winner` reason codes.

# %%
if golden_set_path.exists():
    golden_set = json.loads(golden_set_path.read_text(encoding='utf-8'))
    golden_set[:5] if isinstance(golden_set, list) else golden_set
else:
    {'status': 'missing', 'next_step': 'Run python -m src.evaluation.run.'}
